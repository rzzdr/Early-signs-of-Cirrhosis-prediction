# %%
# !pip install fasteda
# !pip install opentsne
# Out:
# Collecting fasteda
#   Downloading fasteda-1.0.1.tar.gz (4.7 kB)
# done
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from fasteda) (2.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from fasteda) (1.24.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from fasteda) (3.7.3)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (from fasteda) (0.12.2)
# Requirement already satisfied: missingno in /opt/conda/lib/python3.10/site-packages (from fasteda) (0.5.2)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from fasteda) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fasteda) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fasteda) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fasteda) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fasteda) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fasteda) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fasteda) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fasteda) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fasteda) (2.8.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from missingno->fasteda) (1.11.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->fasteda) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->fasteda) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->fasteda) (1.16.0)
# Building wheels for collected packages: fasteda
# done
#   Created wheel for fasteda: filename=fasteda-1.0.1-py3-none-any.whl size=4723 sha256=41ce04ada1e75f63764b63e1cecb4cfbd7c3c4b4fde1cf8cb254acb2fd714187
#   Stored in directory: /root/.cache/pip/wheels/ed/08/72/0d0ec0d3927d227b38ce9542ec3fa6b975c2e17ad0d046dcee
# Successfully built fasteda
# Installing collected packages: fasteda
# Successfully installed fasteda-1.0.1
# Collecting opentsne
#   Obtaining dependency information for opentsne from https://files.pythonhosted.org/packages/99/89/28a28eaa7b758a9723ade97a81118f05911ff2e48faaab454a6ecea136ca/openTSNE-1.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading openTSNE-1.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.16.6 in /opt/conda/lib/python3.10/site-packages (from opentsne) (1.24.3)
# Requirement already satisfied: scikit-learn>=0.20 in /opt/conda/lib/python3.10/site-packages (from opentsne) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from opentsne) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20->opentsne) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20->opentsne) (3.2.0)
# Downloading openTSNE-1.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 23.6 MB/s eta 0:00:00
# Installing collected packages: opentsne
# Successfully installed opentsne-1.0.1

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from lightgbm import LGBMRegressor, LGBMClassifier, log_evaluation, early_stopping
from catboost import CatBoostRegressor, CatBoostClassifier
from xgboost import XGBRegressor, XGBClassifier
from sklearn.model_selection import cross_val_score, KFold, StratifiedKFold, GroupKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR, SVC
from sklearn.ensemble import AdaBoostRegressor, VotingClassifier, ExtraTreesClassifier, HistGradientBoostingClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.neural_network import MLPRegressor, MLPClassifier
from tqdm import tqdm
from colorama import Fore, Back, Style

from sklearn.metrics import log_loss
pd.set_option('display.max_columns', 500)

from fasteda import fast_eda
from openTSNE import TSNE

# %%
train = pd.read_csv("/kaggle/input/playground-series-s3e26/train.csv")
test = pd.read_csv("/kaggle/input/playground-series-s3e26/test.csv")
original = pd.read_csv("/kaggle/input/cirrhosis-patient-survival-prediction/cirrhosis.csv")
sub = pd.read_csv("/kaggle/input/playground-series-s3e26/sample_submission.csv")

# %%
train["is_generated"] = 1
test["is_generated"] = 1
original["is_generated"] = 0

# %%
BOLD_TXT =  Style.BRIGHT
GREEN_TXT = BOLD_TXT + Fore.GREEN
RESET_TXT = Style.RESET_ALL

# %%
def preprocess(df):

    df["Drug"] = df["Drug"].map({"Placebo": 0, "D-penicillamine": 1})
    df["Sex"] = df["Sex"].map({"M": 0, "F": 1})
    
    for col in ["Ascites", "Hepatomegaly", "Spiders"]:
        df[col] = df[col].map({"N": 0, "Y": 1})
        
    df["Edema"] = df["Edema"].map({"N": 0, "S": 1, "Y": 1})
        
    return df

def scale_data(df):    
    
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df[FEATURES])
    df[FEATURES] = scaled_data
    
    return df

# %%
for df in [train, test, original]:
    df = preprocess(df)
   # df = scale_data(df)

# %%
TARGET = "Status"
FEATURES = [col for col in train.columns if col not in ["id", TARGET]]

FEATURES
# Out:
# ['N_Days',
#  'Drug',
#  'Age',
#  'Sex',
#  'Ascites',
#  'Hepatomegaly',
#  'Spiders',
#  'Edema',
#  'Bilirubin',
#  'Cholesterol',
#  'Albumin',
#  'Copper',
#  'Alk_Phos',
#  'SGOT',
#  'Tryglicerides',
#  'Platelets',
#  'Prothrombin',
#  'Stage',
#  'is_generated']

# %%
train[TARGET] = train[TARGET].map({"D": 0, "CL": 1, "C": 2})
original[TARGET] = original[TARGET].map({"D": 0, "CL": 1, "C": 2})

# %%
TSNE_FEATURES = list(test.drop(columns = ["id", "is_generated"]))

train_tsne = train[TSNE_FEATURES].values
y_tsne = train["Status"].values

# %%
fast_eda(train, target = TARGET)
# Out:
# DataFrame Head:
#    id  N_Days  Drug    Age  Sex  Ascites  Hepatomegaly  Spiders  Edema  \
# 0   0     999     1  21532    0        0             0        0      0
# 1   1    2574     0  19237    1        0             0        0      0
# 2   2    3428     0  13727    1        0             1        1      1
#
#    Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  \
# 0        2.3        316.0     3.35   172.0    1601.0  179.80           63.0
# 1        0.9        364.0     3.54    63.0    1440.0  134.85           88.0
# 2        3.3        299.0     3.55   131.0    1029.0  119.35           50.0
#
#    Platelets  Prothrombin  Stage  Status  is_generated
# 0      394.0          9.7    3.0       0             1
# 1      361.0         11.0    3.0       2             1
# 2      199.0         11.7    4.0       0             1
# DataFrame Tail:
#         id  N_Days  Drug    Age  Sex  Ascites  Hepatomegaly  Spiders  Edema  \
# 7902  7902    1576     1  25873    1        0             0        1      1
# 7903  7903    3584     1  22960    0        0             1        0      0
# 7904  7904    1978     1  19237    1        0             0        0      0
#
#       Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos   SGOT  Tryglicerides  \
# 7902        2.0        225.0     3.19    51.0     933.0  69.75           62.0
# 7903        0.7        248.0     2.75    32.0    1003.0  57.35          118.0
# 7904        0.7        256.0     3.23    22.0     645.0  74.40           85.0
#
#       Platelets  Prothrombin  Stage  Status  is_generated
# 7902      200.0         12.7    2.0       0             1
# 7903      221.0         10.6    4.0       0             1
# 7904      336.0         10.3    3.0       2             1
# ----------------------------------------------------------------------------------------------------
# Missing values:
# <style type="text/css">
# </style>
# <table id="T_68e38">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68e38_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# ----------------------------------------------------------------------------------------------------
# Shape of DataFrame:
#
# (7905, 21)
#
# ----------------------------------------------------------------------------------------------------
# DataFrame Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7905 entries, 0 to 7904
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             7905 non-null   int64
#  1   N_Days         7905 non-null   int64
#  2   Drug           7905 non-null   int64
#  3   Age            7905 non-null   int64
#  4   Sex            7905 non-null   int64
#  5   Ascites        7905 non-null   int64
#  6   Hepatomegaly   7905 non-null   int64
#  7   Spiders        7905 non-null   int64
#  8   Edema          7905 non-null   int64
#  9   Bilirubin      7905 non-null   float64
#  10  Cholesterol    7905 non-null   float64
#  11  Albumin        7905 non-null   float64
#  12  Copper         7905 non-null   float64
#  13  Alk_Phos       7905 non-null   float64
#  14  SGOT           7905 non-null   float64
#  15  Tryglicerides  7905 non-null   float64
#  16  Platelets      7905 non-null   float64
#  17  Prothrombin    7905 non-null   float64
#  18  Stage          7905 non-null   float64
#  19  Status         7905 non-null   int64
#  20  is_generated   7905 non-null   int64
# dtypes: float64(10), int64(11)
# memory usage: 1.3 MB
# ----------------------------------------------------------------------------------------------------
# Describe DataFrame:
# /opt/conda/lib/python3.10/site-packages/fasteda/__init__.py:76: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skew_ = df._get_numeric_data().dropna().apply(lambda x: skew(x)).to_frame(name = "skewness")
# /opt/conda/lib/python3.10/site-packages/fasteda/__init__.py:77: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurt_ = df._get_numeric_data().dropna().apply(lambda x: kurtosis(x)).to_frame(name = "kurtosis")
# <style type="text/css">
# #T_477d1_row0_col0, #T_477d1_row0_col4, #T_477d1_row1_col0, #T_477d1_row2_col0, #T_477d1_row2_col1, #T_477d1_row2_col2, #T_477d1_row2_col3, #T_477d1_row2_col4, #T_477d1_row2_col5, #T_477d1_row2_col6, #T_477d1_row2_col7, #T_477d1_row2_col8, #T_477d1_row3_col0, #T_477d1_row4_col0, #T_477d1_row4_col1, #T_477d1_row4_col2, #T_477d1_row4_col3, #T_477d1_row4_col4, #T_477d1_row4_col5, #T_477d1_row4_col6, #T_477d1_row4_col7, #T_477d1_row4_col8, #T_477d1_row5_col0, #T_477d1_row5_col1, #T_477d1_row5_col2, #T_477d1_row5_col3, #T_477d1_row5_col4, #T_477d1_row5_col5, #T_477d1_row5_col6, #T_477d1_row5_col7, #T_477d1_row5_col8, #T_477d1_row6_col0, #T_477d1_row6_col1, #T_477d1_row6_col2, #T_477d1_row6_col3, #T_477d1_row6_col4, #T_477d1_row6_col5, #T_477d1_row6_col6, #T_477d1_row6_col7, #T_477d1_row6_col8, #T_477d1_row7_col0, #T_477d1_row7_col1, #T_477d1_row7_col2, #T_477d1_row7_col3, #T_477d1_row7_col4, #T_477d1_row7_col5, #T_477d1_row7_col6, #T_477d1_row7_col7, #T_477d1_row7_col8, #T_477d1_row8_col0, #T_477d1_row8_col1, #T_477d1_row8_col2, #T_477d1_row8_col3, #T_477d1_row8_col4, #T_477d1_row8_col5, #T_477d1_row8_col6, #T_477d1_row8_col7, #T_477d1_row8_col8, #T_477d1_row9_col0, #T_477d1_row9_col1, #T_477d1_row9_col2, #T_477d1_row9_col3, #T_477d1_row9_col4, #T_477d1_row9_col5, #T_477d1_row9_col6, #T_477d1_row9_col7, #T_477d1_row9_col8, #T_477d1_row10_col0, #T_477d1_row11_col0, #T_477d1_row11_col1, #T_477d1_row11_col2, #T_477d1_row11_col3, #T_477d1_row11_col4, #T_477d1_row11_col5, #T_477d1_row11_col6, #T_477d1_row11_col7, #T_477d1_row11_col8, #T_477d1_row12_col0, #T_477d1_row12_col2, #T_477d1_row12_col4, #T_477d1_row12_col5, #T_477d1_row12_col6, #T_477d1_row13_col0, #T_477d1_row14_col0, #T_477d1_row14_col4, #T_477d1_row15_col0, #T_477d1_row15_col4, #T_477d1_row16_col0, #T_477d1_row17_col0, #T_477d1_row17_col1, #T_477d1_row17_col2, #T_477d1_row17_col3, #T_477d1_row17_col4, #T_477d1_row17_col5, #T_477d1_row17_col6, #T_477d1_row17_col7, #T_477d1_row17_col8, #T_477d1_row18_col0, #T_477d1_row18_col1, #T_477d1_row18_col2, #T_477d1_row18_col3, #T_477d1_row18_col4, #T_477d1_row18_col5, #T_477d1_row18_col6, #T_477d1_row18_col7, #T_477d1_row18_col8, #T_477d1_row19_col0, #T_477d1_row19_col1, #T_477d1_row19_col2, #T_477d1_row19_col3, #T_477d1_row19_col4, #T_477d1_row19_col5, #T_477d1_row19_col6, #T_477d1_row19_col7, #T_477d1_row19_col8, #T_477d1_row20_col0, #T_477d1_row20_col1, #T_477d1_row20_col2, #T_477d1_row20_col3, #T_477d1_row20_col4, #T_477d1_row20_col5, #T_477d1_row20_col6, #T_477d1_row20_col7, #T_477d1_row20_col8 {
#   background-color: #9e0142;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row0_col1 {
#   background-color: #f57748;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row0_col2, #T_477d1_row0_col6 {
#   background-color: #f57547;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row0_col3 {
#   background-color: #daf09a;
#   color: #000000;
#   font-weight: bold;
# }
# #T_477d1_row0_col5 {
#   background-color: #dd4a4c;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row0_col7 {
#   background-color: #fca55d;
#   color: #000000;
#   font-weight: bold;
# }
# #T_477d1_row0_col8 {
#   background-color: #fb9d59;
#   color: #000000;
#   font-weight: bold;
# }
# #T_477d1_row0_col9, #T_477d1_row20_col9, #T_477d1_row20_col10 {
#   color: #FFFFFF;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_477d1_row0_col10, #T_477d1_row1_col10, #T_477d1_row2_col10, #T_477d1_row3_col10, #T_477d1_row4_col9, #T_477d1_row6_col9, #T_477d1_row6_col10, #T_477d1_row7_col10, #T_477d1_row11_col9, #T_477d1_row18_col9, #T_477d1_row18_col10, #T_477d1_row19_col9, #T_477d1_row19_col10 {
#   color: #ff0000;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_477d1_row1_col1 {
#   background-color: #d8434e;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row1_col2, #T_477d1_row1_col6, #T_477d1_row13_col1 {
#   background-color: #d43d4f;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row1_col3 {
#   background-color: #fdad60;
#   color: #000000;
#   font-weight: bold;
# }
# #T_477d1_row1_col4, #T_477d1_row12_col1, #T_477d1_row12_col7, #T_477d1_row14_col1, #T_477d1_row14_col2, #T_477d1_row14_col5, #T_477d1_row14_col6, #T_477d1_row14_col7, #T_477d1_row15_col1, #T_477d1_row15_col2, #T_477d1_row15_col5, #T_477d1_row15_col6, #T_477d1_row15_col7, #T_477d1_row16_col4 {
#   background-color: #a00343;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row1_col5 {
#   background-color: #c9314c;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row1_col7 {
#   background-color: #de4c4b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row1_col8 {
#   background-color: #e95c47;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row1_col9, #T_477d1_row2_col9, #T_477d1_row3_col9, #T_477d1_row4_col10, #T_477d1_row5_col9, #T_477d1_row5_col10, #T_477d1_row7_col9, #T_477d1_row8_col9, #T_477d1_row8_col10, #T_477d1_row9_col9, #T_477d1_row9_col10, #T_477d1_row10_col9, #T_477d1_row10_col10, #T_477d1_row11_col10, #T_477d1_row12_col9, #T_477d1_row12_col10, #T_477d1_row13_col9, #T_477d1_row13_col10, #T_477d1_row14_col9, #T_477d1_row14_col10, #T_477d1_row15_col9, #T_477d1_row15_col10, #T_477d1_row16_col9, #T_477d1_row16_col10, #T_477d1_row17_col9, #T_477d1_row17_col10 {
#   color: #00ff00;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_477d1_row3_col1, #T_477d1_row3_col2, #T_477d1_row3_col3, #T_477d1_row3_col4, #T_477d1_row3_col5, #T_477d1_row3_col6, #T_477d1_row3_col7, #T_477d1_row3_col8 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row10_col1, #T_477d1_row10_col2, #T_477d1_row10_col5, #T_477d1_row10_col6, #T_477d1_row10_col7, #T_477d1_row14_col8 {
#   background-color: #a70b44;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row10_col3, #T_477d1_row13_col5 {
#   background-color: #ba2049;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row10_col4, #T_477d1_row14_col3, #T_477d1_row15_col3, #T_477d1_row16_col1, #T_477d1_row16_col2, #T_477d1_row16_col5, #T_477d1_row16_col6, #T_477d1_row16_col7 {
#   background-color: #a40844;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row10_col8 {
#   background-color: #be254a;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row12_col3, #T_477d1_row12_col8, #T_477d1_row15_col8, #T_477d1_row16_col8 {
#   background-color: #a90d45;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row13_col2, #T_477d1_row13_col6 {
#   background-color: #c1274a;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row13_col3 {
#   background-color: #fbfdb8;
#   color: #000000;
#   font-weight: bold;
# }
# #T_477d1_row13_col4 {
#   background-color: #ad1246;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row13_col7 {
#   background-color: #cd364d;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_477d1_row13_col8 {
#   background-color: #fffab6;
#   color: #000000;
#   font-weight: bold;
# }
# #T_477d1_row16_col3 {
#   background-color: #ab0f45;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# </style>
# <table id="T_477d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_477d1_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_477d1_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_477d1_level0_col2" class="col_heading level0 col2" >median</th>
#       <th id="T_477d1_level0_col3" class="col_heading level0 col3" >std</th>
#       <th id="T_477d1_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_477d1_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_477d1_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_477d1_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_477d1_level0_col8" class="col_heading level0 col8" >max</th>
#       <th id="T_477d1_level0_col9" class="col_heading level0 col9" >skewness</th>
#       <th id="T_477d1_level0_col10" class="col_heading level0 col10" >kurtosis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_477d1_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_477d1_row0_col0" class="data row0 col0" >7905</td>
#       <td id="
# ----------------------------------------------------------------------------------------------------
# DataFrame Correlation:
# ----------------------------------------------------------------------------------------------------
# Histogram(s) & Boxplot(s):
# ----------------------------------------------------------------------------------------------------
# Countplot(s):

# %%
# %%time
plot_tsne = TSNE().fit(train_tsne)
# Out:
# CPU times: user 7min 30s, sys: 1.05 s, total: 7min 31s
# Wall time: 7min 32s

# %%
plt.style.use("dark_background")
plt.figure(figsize = (12, 10))

marker_sizes = [15 if hue == 1 else 3 for hue in y_tsne]

ax = sns.scatterplot(x = plot_tsne[:,0], y = plot_tsne[:,1], s = marker_sizes, hue = y_tsne,
                     linewidth = 0, palette = ["#ff3300", "#ffffff", "#33cc33"])
plt.grid(False)
plt.title(f"TSNE plot w/ target = {TARGET} | train data")
plt.show()

# %%
def train_model(train_data, model, features, n_splits, kfold_seed, include_orig):
    
    model_name = str(model).split("(")[0]
    test_preds = np.zeros((len(test), 3))
    oof_full = np.zeros((len(train_data), 3))
    val_scores, models = [], []
    
    print(model_name)
    
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=kfold_seed)
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=kfold_seed)
    
    for i, (train_idx, val_idx) in enumerate(tqdm(skf.split(train_data[features], train_data[TARGET]))):

        X_train, X_val = train_data[features].loc[train_idx], train_data[features].loc[val_idx]
        y_train, y_val = train_data[TARGET].loc[train_idx], train_data[TARGET].loc[val_idx]
        
        if include_orig:
            X_train = pd.concat([X_train, original[features]], ignore_index = True)
            y_train = pd.concat([y_train, original[TARGET]], ignore_index = True)
        
        if model_name in ["LGBMRegressor", "LGBMClassifier"]:
            callbacks = [early_stopping(stopping_rounds=50)]
            model.fit(X_train, y_train, eval_set=[(X_val, y_val)], callbacks=callbacks)
        elif model_name in ["XGBClassifier", "CatBoostClassifier"]:
            model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=10000)
        else:
            model.fit(X_train, y_train)
        
        oof_preds = model.predict_proba(X_val[features])
        test_preds += model.predict_proba(test[features]) / n_splits
 
        oof_full[val_idx] = oof_preds
        score = log_loss(y_val, oof_preds)
        
        models.append(model)
        val_scores.append(score)
            
        print(f"{GREEN_TXT}FOLD {i + 1} log_loss: {round(score, 4)}{RESET_TXT}")
        
    print(f'{GREEN_TXT}mean log_loss across all folds: {np.mean(val_scores):.5f}{RESET_TXT}')
    print(f'{GREEN_TXT}std of log_loss across all folds: {np.std(val_scores):.5f}{RESET_TXT}')
    
    return oof_full, test_preds, models

# %%
xgb_params = {
    'objective': 'multi_logloss', 
    'max_depth': 9, 
    'learning_rate': 0.034869481921747415, 
    'n_estimators': 10000,
    'early_stopping_rounds': 50,
    'min_child_weight': 9, 
    'colsample_bytree': 0.2, 
    'reg_alpha': 0.10626128775335533, 
    'reg_lambda': 0.624196407787772, 
    'random_state': 42
}

lgb_params = {
    'objective': 'multi_logloss', 
    'max_depth': 9, 
    'min_child_samples': 14, 
    'learning_rate': 0.034869481921747415, 
    'n_estimators': 100000, 
    'min_child_weight': 9, 
    'colsample_bytree': 0.1702910221565107, 
    'reg_alpha': 0.10626128775335533, 
    'reg_lambda': 0.624196407787772, 
    'random_state': 42
}

# %%
xgb_oof_preds, xgb_test_preds, xgb_models = train_model(
    train_data = train,
    model = XGBClassifier(**xgb_params),
    features = FEATURES,
    n_splits = 10,
    kfold_seed = 0,
    include_orig = True
)
# Out:
# XGBClassifier
# 0it [00:00, ?it/s]
# [0]	validation_0-mlogloss:1.07670
# [370]	validation_0-mlogloss:0.41581
# 1it [00:02,  2.30s/it]
# FOLD 1 log_loss: 0.414
# [0]	validation_0-mlogloss:1.07692
# [376]	validation_0-mlogloss:0.42659
# 2it [00:04,  2.30s/it]
# FOLD 2 log_loss: 0.4263
# [0]	validation_0-mlogloss:1.07684
# [378]	validation_0-mlogloss:0.42527
# 3it [00:08,  2.87s/it]
# FOLD 3 log_loss: 0.4243
# [0]	validation_0-mlogloss:1.07682
# [415]	validation_0-mlogloss:0.40604
# 4it [00:10,  2.73s/it]
# FOLD 4 log_loss: 0.4058
# [0]	validation_0-mlogloss:1.07758
# [400]	validation_0-mlogloss:0.41734
# 5it [00:13,  2.62s/it]
# FOLD 5 log_loss: 0.4161
# [0]	validation_0-mlogloss:1.07704
# [367]	validation_0-mlogloss:0.43190
# 6it [00:15,  2.49s/it]
# FOLD 6 log_loss: 0.4317
# [0]	validation_0-mlogloss:1.07730
# [384]	validation_0-mlogloss:0.39623
# 7it [00:17,  2.45s/it]
# FOLD 7 log_loss: 0.3958
# [0]	validation_0-mlogloss:1.07705
# [347]	validation_0-mlogloss:0.42235
# 8it [00:19,  2.34s/it]
# FOLD 8 log_loss: 0.4217
# [0]	validation_0-mlogloss:1.07750
# [387]	validation_0-mlogloss:0.44060
# 9it [00:22,  2.33s/it]
# FOLD 9 log_loss: 0.4395
# [0]	validation_0-mlogloss:1.07719
# [388]	validation_0-mlogloss:0.41370
# 10it [00:24,  2.44s/it]
# FOLD 10 log_loss: 0.4127
# mean log_loss across all folds: 0.41879
# std of log_loss across all folds: 0.01205

# %%
lgb_oof_preds, lgb_test_preds, lgb_models = train_model(
    train_data = train,
    model = LGBMClassifier(**lgb_params),
    features = FEATURES,
    n_splits = 10,
    kfold_seed = 0,
    include_orig = True
)
# Out:
# LGBMClassifier
# 0it [00:00, ?it/s]
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [280]	valid_0's multi_logloss: 0.415507
# 1it [00:06,  6.46s/it]
# FOLD 1 log_loss: 0.4155
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [290]	valid_0's multi_logloss: 0.430072
# 2it [00:13,  6.95s/it]
# FOLD 2 log_loss: 0.4301
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [254]	valid_0's multi_logloss: 0.427764
# 3it [00:19,  6.61s/it]
# FOLD 3 log_loss: 0.4278
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [329]	valid_0's multi_logloss: 0.40904
# 4it [00:27,  6.92s/it]
# FOLD 4 log_loss: 0.409
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [355]	valid_0's multi_logloss: 0.4166
# 5it [00:35,  7.32s/it]
# FOLD 5 log_loss: 0.4166
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [292]	valid_0's multi_logloss: 0.437672
# 6it [00:42,  7.13s/it]
# FOLD 6 log_loss: 0.4377
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [286]	valid_0's multi_logloss: 0.398709
# 7it [00:49,  7.24s/it]
# FOLD 7 log_loss: 0.3987
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [291]	valid_0's multi_logloss: 0.419917
# 8it [00:56,  7.07s/it]
# FOLD 8 log_loss: 0.4199
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [253]	valid_0's multi_logloss: 0.44225
# 9it [01:02,  6.77s/it]
# FOLD 9 log_loss: 0.4422
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [309]	valid_0's multi_logloss: 0.420683
# 10it [01:09,  6.93s/it]
# FOLD 10 log_loss: 0.4207
# mean log_loss across all folds: 0.42182
# std of log_loss across all folds: 0.01242

# %%
sub[f"{TARGET}_D"] =  xgb_test_preds[:, 0] * 0.5 + lgb_test_preds[:, 0] * 0.5
sub[f"{TARGET}_CL"] = xgb_test_preds[:, 1] * 0.5 + lgb_test_preds[:, 1] * 0.5
sub[f"{TARGET}_C"] =  xgb_test_preds[:, 2] * 0.5 + lgb_test_preds[:, 2] * 0.5
sub.head(3)
# Out:
#      id  Status_C  Status_CL  Status_D
# 0  7905  0.396938   0.036025  0.567036
# 1  7906  0.472695   0.254665  0.272640
# 2  7907  0.045066   0.013980  0.940954

# %%
plt.style.use("default")
plt.figure(figsize = (12, 10))

sns.histplot(df, x = sub["Status_C"], kde = True, label = "Status_C")
sns.histplot(df, x = sub["Status_CL"], kde = True, label = "Status_CL")
sns.histplot(df, x = sub["Status_D"], kde = True, label = "Status_D")

plt.xlabel("Predictions")
plt.legend()
plt.show()

# %%
sub.to_csv("submission.csv", index = False)
